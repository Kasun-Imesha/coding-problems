# %% [markdown]
# # Searching

# %% [markdown]
# ## Binary Search

# %% [markdown]
# Search elements in an **sorted** array

# %%
# binary search
def binary_search(arr, ele):
    mid = len(arr) // 2

    if len(arr) == 1:
        if arr[0] == ele:
            return ele   
        else:
            return None 

    if arr[mid] == ele:
        return ele

    elif arr[mid] < ele:
        return binary_search(arr[mid+1:], ele)

    else:
        return binary_search(arr[:mid], ele)

def binary_search_index(arr, ele, low, high):
    if low > high:
        return None
        
    mid = (low + high) // 2

    if arr[mid] == ele:
        return mid

    elif arr[mid] < ele:
        low = mid + 1

    else:
        high = mid - 1

    return binary_search_index(arr, ele, low, high)


a = [2, 4, 5, 7, 8, 10]

for x in [1, 2, 7, 9, 10]:
    print(f"{x} --> available: {binary_search(a, x) is not None}")

print("--" * 10)

for x in [1, 2, 7, 9, 10]:
    print(f"{x} --> index: {binary_search_index(a, x, 0, len(a) - 1)}")
# Out:
# 1 --> available: False
# 2 --> available: True
# 7 --> available: True
# 9 --> available: False
# 10 --> available: True
# --------------------
# 1 --> index: None
# 2 --> index: 0
# 7 --> index: 3
# 9 --> index: None
# 10 --> index: 5

# %% [markdown]
# # Sorting

# %% [markdown]
# ## Insertion Sort

# %% [markdown]
# Insertion sort is a simple sorting algorithm that works by iteratively inserting each element of an unsorted list into its correct position in a sorted portion of the list. It is like sorting playing cards in your hands. You split the cards into two groups: the sorted cards and the unsorted cards. Then, you pick a card from the unsorted group and put it in the right place in the sorted group.
#
# Start with the second element as the first element is assumed to be sorted.
# Compare the second element with the first if the second is smaller then swap them.
# Move to the third element, compare it with the first two, and put it in its correct position
# Repeat until the entire array is sorted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def insertion_sort(arr: list) -> list:
    for i in range(1, len(arr)):
        key = arr[i]
        j = i -1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    
    return arr


a = [2, 4, 5, 7, 8, 10]
b = [10, 8, 7, 5, 4, 2]
c = [8, 7, 2, 10, 5, 4]
d = [8, 7, 2, 10, 5, 4, 7]
e = [8, 7, 2, 10, 5, 4, 3]

for arr in [a, b, c, d, e]:
    print(f"insertion_sort result of {arr} --> {insertion_sort(arr)}")
# Out:
# insertion_sort result of [2, 4, 5, 7, 8, 10] --> [2, 4, 5, 7, 8, 10]
# insertion_sort result of [10, 8, 7, 5, 4, 2] --> [2, 4, 5, 7, 8, 10]
# insertion_sort result of [8, 7, 2, 10, 5, 4] --> [2, 4, 5, 7, 8, 10]
# insertion_sort result of [8, 7, 2, 10, 5, 4, 7] --> [2, 4, 5, 7, 7, 8, 10]
# insertion_sort result of [8, 7, 2, 10, 5, 4, 3] --> [2, 3, 4, 5, 7, 8, 10]

# %% [markdown]
# ## Merge Sort

# %%
def merge_1(arr1, arr2):
    i = 0
    j = 0
    k = 0
    l1 = len(arr1)
    l2 = len(arr2)
    arr = [None] * (l1 + l2)

    while i < l1 and j < l2:

        if arr1[i] < arr2[j]:
            arr[k] = arr1[i]
            i += 1
        else:
            arr[k] = arr2[j]
            j += 1

        k += 1

    if i < l1:
        for ele in arr1[i:]:
            arr[k] = ele
            k += 1
    elif j < l2:
        for ele in arr2[j:]:
            arr[k] = ele
            k += 1

    return arr

def merge_sort_1(arr):

    if len(arr) == 1:
        # print(arr)
        return arr

    mid = len(arr) // 2

    l_arr = arr[: mid]
    r_arr = arr[mid:]

    # print(f"{l_arr} -- {r_arr}")

    arr1 = merge_sort_1(l_arr)
    arr2 = merge_sort_1(r_arr)

    return merge_1(arr1, arr2)

# d = c
# print(merge([4,6,9], [1, 2, 10]))
# print(f"original arr: {d}")
# print(merge_sort(d))
# for arr in [a, b, c, d, e]:
#     print(f"merge_sort result of {arr} --> {merge_sort_1(arr)}")

def merge(a1, a2):
    i = 0
    j = 0
    k = 0
    l1 = len(a1)
    l2 = len(a2)
    arr = [None] * (l1 + l2)

    while i < l1 and j < l2:
        if a1[i] < a2[j]:
            arr[k] = a1[i]
            i += 1
        else:
            arr[k] = a2[j]
            j += 1

        k += 1

    if i < l1:
        for ele in a1[i:]:
            arr[k] = ele
            k += 1
    elif j < l2:
        for ele in a2[j:]:
            arr[k] = ele
            k += 1

    return arr

def merge_sort(arr):
    if len(arr) == 1:
        return arr

    mid = len(arr) // 2

    arr1 = merge_sort(arr[:mid])
    arr2 = merge_sort(arr[mid:])

    return merge(arr1, arr2)


a = [2, 4, 5, 7, 8, 10]
b = [10, 8, 7, 5, 4, 2]
c = [8, 7, 2, 10, 5, 4]
d = [8, 7, 2, 10, 5, 4, 7]
e = [8, 7, 2, 10, 5, 4, 3]

for arr in [a, b, c, d, e]:
    print(f"merge_sort result of {arr} --> {merge_sort(arr)}")
# Out:
# merge_sort result of [2, 4, 5, 7, 8, 10] --> [2, 4, 5, 7, 8, 10]
# merge_sort result of [10, 8, 7, 5, 4, 2] --> [2, 4, 5, 7, 8, 10]
# merge_sort result of [8, 7, 2, 10, 5, 4] --> [2, 4, 5, 7, 8, 10]
# merge_sort result of [8, 7, 2, 10, 5, 4, 7] --> [2, 4, 5, 7, 7, 8, 10]
# merge_sort result of [8, 7, 2, 10, 5, 4, 3] --> [2, 3, 4, 5, 7, 8, 10]

# %% [markdown]
# ## Bubble Sort

# %%
def bubble_sort(arr):
    while True:
        swapped = False

        for i in range(len(arr) - 1):
        
            if arr[i] > arr[i + 1]:
                ######
                arr[i], arr[i + 1] = arr[i + 1], arr[i]
                #####
                # tmp = arr[i]
                # arr[i] = arr[i + 1]
                # arr[i + 1] = tmp
                #####
                # arr[i] = arr[i] + arr[i + 1]
                # arr[i + 1] = arr[i] - arr[i + 1]
                # arr[i] = arr[i] - arr[i + 1]

                swapped = True

        if not swapped:
            break

    return arr

a = [2, 4, 5, 7, 8, 10]
b = [10, 8, 7, 5, 4, 2]
c = [8, 7, 2, 10, 5, 4]
d = [8, 7, 2, 10, 5, 4, 7]
e = [8, 7, 2, 10, 5, 4, 3]

for arr in [a, b, c, d, e]:
    print(f"bubble_sort result of {arr} --> {bubble_sort(arr)}")
# Out:
# bubble_sort result of [2, 4, 5, 7, 8, 10] --> [2, 4, 5, 7, 8, 10]
# bubble_sort result of [10, 8, 7, 5, 4, 2] --> [2, 4, 5, 7, 8, 10]
# bubble_sort result of [8, 7, 2, 10, 5, 4] --> [2, 4, 5, 7, 8, 10]
# bubble_sort result of [8, 7, 2, 10, 5, 4, 7] --> [2, 4, 5, 7, 7, 8, 10]
# bubble_sort result of [8, 7, 2, 10, 5, 4, 3] --> [2, 3, 4, 5, 7, 8, 10]
